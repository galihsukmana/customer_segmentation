# %% [markdown]
# ## Model Inference

# %%
# Import Library

import pickle
import joblib
import json
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Model

# %%
with open('model.pkl', 'rb') as file_1:
  model_clus = pickle.load(file_1)

with open('model_scaler.pkl', 'rb') as file_2:
  scaler = pickle.load(file_2)

# with open('model_encoder.pkl', 'rb') as file_3:
#   encoder = pickle.load(file_3)

with open('list_num_cols.txt', 'r') as file_3:
  num_col = json.load(file_3)

with open('list_cat_cols.txt','r') as file_4: 
  cat_col = json.load(file_4)

with open('pipeline.pkl','rb') as file_5:
  pipe = pickle.load(file_5)

# num_pipeline = joblib.load('num_pipeline_model.joblib')
# cat_pipeline = joblib.load('cat_pipeline_model.joblib')
# full_pipeline = joblib.load('pipeline_model.joblib')

# %% [markdown]
# ## Inferencing

# %%
df = pd.read_csv('data_inferences.csv')
inf = df.tail(5).reset_index().drop(['index','Unnamed: 0'],axis=1)
inf
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     2345  9629.808851                1.0        0.0               0.0
# 1     6785  1040.030221                1.0        0.0               0.0
# 2     7347  1322.818587                1.0        0.0               0.0
# 3     8447  1060.391273                1.0        0.0               0.0
# 4     1995  3447.674222                1.0      205.0             205.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                     0.0   4372.393835             0.000000
# 1                     0.0   1390.648290             0.000000
# 2                     0.0    762.301096             0.000000
# 3                     0.0   1475.858013             0.000000
# 4                     0.0   4548.057776             0.090909
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                               0.0
# ...

# %%
# Split between Numerical Columns and Categorical Columns

data_inf_num = inf[num_col]
data_inf_cat = inf[cat_col]
data_inf_num
# Out:
#    CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     2345  9629.808851                1.0        0.0               0.0
# 1     6785  1040.030221                1.0        0.0               0.0
# 2     7347  1322.818587                1.0        0.0               0.0
# 3     8447  1060.391273                1.0        0.0               0.0
# 4     1995  3447.674222                1.0      205.0             205.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                     0.0   4372.393835             0.000000
# 1                     0.0   1390.648290             0.000000
# 2                     0.0    762.301096             0.000000
# 3                     0.0   1475.858013             0.000000
# 4                     0.0   4548.057776             0.090909
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                               0.0
# ...

# %%
data_pipe = pipe.fit_transform(data_inf_num)

# %%
model_clus.fit_predict(data_pipe)
# Out:
# array([2, 0, 0, 0, 1], dtype=int32)

# %% [markdown]
# Data telah terprediksi
